# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! unzip /content/drive/MyDrive/HandGestures/data/LeapMotion/imgs.zip
# ! unzip /content/drive/MyDrive/HandGestures/data/TinyHGRSubset/subset_imgs.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: pictures/ThumbDown/Thumb30.png
#   inflating: pictures/ThumbDown/Thumb24.png
#   inflating: pictures/ThumbDown/Thumb279.png
#   inflating: pictures/ThumbDown/Thumb1248.png
#   inflating: pictures/ThumbDown/Thumb251.png
#   inflating: pictures/ThumbDown/Thumb1260.png
#   inflating: pictures/ThumbDown/Thumb1506.png
#   inflating: pictures/ThumbDown/Thumb537.png
#   inflating: pictures/ThumbDown/Thumb523.png
#   inflating: pictures/ThumbDown/Thumb1512.png
#   inflating: pictures/ThumbDown/Thumb18.png
#   inflating: pictures/ThumbDown/Thumb1274.png
#   inflating: pictures/ThumbDown/Thumb245.png
#   inflating: pictures/ThumbDown/Thumb292.png
#   inflating: pictures/ThumbDown/Thumb286.png
#   inflating: pictures/ThumbDown/Thumb1738.png
#   inflating: pictures/ThumbDown/Thumb709.png
#   inflating: pictures/ThumbDown/Thumb735.png
#   inflating: pictures/ThumbDown/Thumb1704.png
#   inflating: pictures/ThumbDown/Thumb1062.png
#   inflating: pictures/ThumbDown/Thumb1076.png
#   inflating: pictures/ThumbDown/Thumb1710.png
#   inflating: pictures/ThumbDown/Thumb721.png
#   inflating: pictures/ThumbDown/Thumb912.png
#   inflating: pictures/ThumbDown/Thumb1923.png
#   inflating: pictures/ThumbDown/Thumb1089.png
#   inflating: pictures/ThumbDown/Thumb1937.png
#   inflating: pictures/ThumbDown/Thumb906.png
#   inflating: pictures/ThumbDown/Thumb1894.png
#   inflating: pictures/ThumbDown/Thumb669.png
#   inflating: pictures/ThumbDown/Thumb1658.png
#   inflating: pictures/ThumbDown/Thumb1880.png
#   inflating: pictures/ThumbDown/Thumb899.png
#   inflating: pictures/ThumbDown/Thumb641.png
#   inflating: pictures/ThumbDown/Thumb1670.png
#   inflating: pictures/ThumbDown/Thumb1116.png
#   inflating: pictures/ThumbDown/Thumb127.png
#   inflating: pictures/ThumbDown/Thumb133.png
#   inflating: pictures/ThumbDown/Thumb1102.png
#   inflating: pictures/ThumbDown/Thumb1664.png
#   inflating: pictures/ThumbDown/Thumb655.png
#   inflating: pictures/ThumbDown/Thumb866.png
#   inflating: pictures/ThumbDown/Thumb1857.png
#   inflating: pictures/ThumbDown/Thumb1843.png
#   inflating: pictures/ThumbDown/Thumb872.png
#   inflating: pictures/ThumbDown/Thumb682.png
#   inflating: pictures/ThumbDown/Thumb696.png
#   inflating: pictures/ThumbDown/Thumb1328.png
#   inflating: pictures/ThumbDown/Thumb319.png
#   inflating: pictures/ThumbDown/Thumb325.png
#   inflating: pictures/ThumbDown/Thumb1314.png
#   inflating: pictures/ThumbDown/Thumb1472.png
#   inflating: pictures/ThumbDown/Thumb443.png
#   inflating: pictures/ThumbDown/Thumb457.png
#   inflating: pictures/ThumbDown/Thumb1466.png
#   inflating: pictures/ThumbDown/Thumb1300.png
#   inflating: pictures/ThumbDown/Thumb331.png
#   inflating: pictures/ThumbDown/Thumb1499.png
#   inflating: pictures/ThumbDown/Thumb480.png
#   inflating: pictures/ThumbDown/Thumb494.png
#   inflating: pictures/ThumbDown/Thumb495.png
#   inflating: pictures/ThumbDown/Thumb481.png
#   inflating: pictures/ThumbDown/Thumb1498.png
#   inflating: pictures/ThumbDown/Thumb1467.png
#   inflating: pictures/ThumbDown/Thumb456.png
#   inflating: pictures/ThumbDown/Thumb330.png
#   inflating: pictures/ThumbDown/Thumb1301.png
#   inflating: pictures/ThumbDown/Thumb1315.png
#   inflating: pictures/ThumbDown/Thumb324.png
#   inflating: pictures/ThumbDown/Thumb442.png
#   inflating: pictures/ThumbDown/Thumb1473.png
#   inflating: pictures/ThumbDown/Thumb318.png
#   inflating: pictures/ThumbDown/Thumb1329.png
#   inflating: pictures/ThumbDown/Thumb697.png
#   inflating: pictures/ThumbDown/Thumb683.png
#   inflating: pictures/ThumbDown/Thumb873.png
#   inflating: pictures/ThumbDown/Thumb1842.png
#   inflating: pictures/ThumbDown/Thumb1856.png
#   inflating: pictures/ThumbDown/Thumb867.png
#   inflating: pictures/ThumbDown/Thumb1103.png
#   inflating: pictures/ThumbDown/Thumb132.png
#   inflating: pictures/ThumbDown/Thumb654.png
#   inflating: pictures/ThumbDown/Thumb1665.png
#   inflating: pictures/ThumbDown/Thumb1671.png
#   inflating: pictures/ThumbDown/Thumb640.png
#   inflating: pictures/ThumbDown/Thumb898.png
#   inflating: pictures/ThumbDown/Thumb126.png
#   inflating: pictures/ThumbDown/Thumb1117.png
#   inflating: pictures/ThumbDown/Thumb1881.png
#   inflating: pictures/ThumbDown/Thumb1659.png
#   inflating: pictures/ThumbDown/Thumb668.png
#   inflating: pictures/ThumbDown/Thumb1895.png
#   inflating: pictures/ThumbDown/Thumb1088.png
#   inflating: pictures/ThumbDown/Thumb907.png
#   inflating: pictures/ThumbDown/Thumb1936.png
#   inflating: pictures/ThumbDown/Thumb1922.png
#   inflating: pictures/ThumbDown/Thumb913.png
#   inflating: pictures/ThumbDown/Thumb1077.png
#   inflating: pictures/ThumbDown/Thumb720.png
#   inflating: pictures/ThumbDown/Thumb1711.png
#   inflating: pictures/ThumbDown/Thumb1705.png
#   inflating: pictures/ThumbDown/Thumb734.png
#   inflating: pictures/ThumbDown/Thumb1063.png
#   inflating: pictures/ThumbDown/Thumb708.png
#   inflating: pictures/ThumbDown/Thumb1739.png
#   inflating: pictures/ThumbDown/Thumb287.png
#   inflating: pictures/ThumbDown/Thumb293.png
#   inflating: pictures/ThumbDown/Thumb19.png
#   inflating: pictures/ThumbDown/Thumb1513.png
#   inflating: pictures/ThumbDown/Thumb522.png
#   inflating: pictures/ThumbDown/Thumb244.png
#   inflating: pictures/ThumbDown/Thumb1275.png
#   inflating: pictures/ThumbDown/Thumb1261.png
#   inflating: pictures/ThumbDown/Thumb250.png
#   inflating: pictures/ThumbDown/Thumb536.png
#   inflating: pictures/ThumbDown/Thumb1507.png
#   inflating: pictures/ThumbDown/Thumb25.png
#   inflating: pictures/ThumbDown/Thumb1249.png
#   inflating: pictures/ThumbDown/Thumb278.png
#   inflating: pictures/ThumbDown/Thumb31.png
#   inflating: pictures/ThumbDown/Thumb27.png
#   inflating: pictures/ThumbDown/Thumb508.png
#   inflating: pictures/ThumbDown/Thumb1539.png
#   inflating: pictures/ThumbDown/Thumb33.png
#   inflating: pictures/ThumbDown/Thumb1277.png
#   inflating: pictures/ThumbDown/Thumb246.png
#   inflating: pictures/ThumbDown/Thumb520.png
#   inflating: pictures/ThumbDown/Thumb1511.png
#   inflating: pictures/ThumbDown/Thumb1505.png
#   inflating: pictures/ThumbDown/Thumb534.png
#   inflating: pictures/ThumbDown/Thumb252.png
#   inflating: pictures/ThumbDown/Thumb1263.png
#   inflating: pictures/ThumbDown/Thumb1288.png
#   inflating: pictures/ThumbDown/Thumb285.png
#   inflating: pictures/ThumbDown/Thumb291.png
#   inflating: pictures/ThumbDown/Thumb1049.png
#   inflating: pictures/ThumbDown/Thumb1713.png
#   inflating: pictures/ThumbDown/Thumb722.png
#   inflating: pictures/ThumbDown/Thumb1075.png
#   inflating: pictures/ThumbDown/Thumb1061.png
#   inflating: pictures/ThumbDown/Thumb736.png
#   inflating: pictures/ThumbDown/Thumb1707.png
#   inflating: pictures/ThumbDown/Thumb1934.png
#   inflating: pictures/ThumbDown/Thumb905.png
#   inflating: pictures/ThumbDown/Thumb911.png
#   inflating: pictures/ThumbDown/Thumb1920.png
#   inflating: pictures/ThumbDown/Thumb939.png
#   inflating: pictures/ThumbDown/Thumb1908.png
#   inflating: pictures/ThumbDown/Thumb1883.png
#   inflating: pictures/ThumbDown/Thumb118.png
#   inflating: pictures/ThumbDown/Thumb1129.png
#   inflating: pictures/ThumbDown/Thumb1897.png
#   inflating: pictures/ThumbDown/Thumb1667.png
#   inflating: pictures/ThumbDown/Thumb656.png
#   inflating: pictures/ThumbDown/Thumb130.png
#   inflating: pictures/ThumbDown/Thumb1101.png
#   inflating: pictures/ThumbDown/Thumb1115.png
#   inflating: pictures/ThumbDown/Thumb124.png
#   inflating: pictures/ThumbDown/Thumb642.png
#   inflating: pictures/ThumbDown/Thumb1673.png
#   inflating: pictures/ThumbDown/Thumb1840.png
#   inflating: pictures/ThumbDown/Thumb1698.png
#   inflating: pictures/ThumbDown/Thumb871.png
#   inflating: pictures/ThumbDown/Thumb865.png
#   inflating: pictures/ThumbDown/Thumb1854.png
#   inflating: pictures/ThumbDown/Thumb695.png
#   inflating: pictures/ThumbDown/Thumb1868.png
#   inflating: pictures/ThumbDown/Thumb681.png
#   inflating: pictures/ThumbDown/Thumb859.png
#   inflating: pictures/ThumbDown/Thumb1459.png
#   inflating: pictures/ThumbDown/Thumb468.png
#   inflating: pictures/ThumbDown/Thumb1303.png
#   inflating: pictures/ThumbDown/Thumb332.png
#   inflating: pictures/ThumbDown/Thumb454.png
#   inflating: pictures/ThumbDown/Thumb1465.png
#   inflating: pictures/ThumbDown/Thumb1471.png
#   inflating: pictures/ThumbDown/Thumb440.png
#   inflating: pictures/ThumbDown/Thumb326.png
#   inflating: pictures/ThumbDown/Thumb1317.png
#   inflating: pictures/ThumbDown/Thumb497.png
#   inflating: pictures/ThumbDown/Thumb483.png
#   inflating: pictures/ThumbDown/Thumb482.png
#   inflating: pictures/ThumbDown/Thumb496.png
#   inflating: pictures/ThumbDown/Thumb441.png
#   inflating: pictures/ThumbDown/Thumb1470.png
#   inflating: pictures/ThumbDown/Thumb1316.png
#   inflating: pictures/ThumbDown/Thumb327.png
#   inflating: pictures/ThumbDown/Thumb333.png
#   inflating: pictures/ThumbDown/Thumb1302.png
#   inflating: pictures/ThumbDown/Thumb1464.png
#   inflating: pictures/ThumbDown/Thumb455.png
#   inflating: pictures/ThumbDown/Thumb469.png
#   inflating: pictures/ThumbDown/Thumb1458.png
#   inflating: pictures/ThumbDown/Thumb858.png
#   inflating: pictures/ThumbDown/Thumb680.png
#   inflating: pictures/ThumbDown/Thumb1869.png
#   inflating: pictures/ThumbDown/Thumb694.png
#   inflating: pictures/ThumbDown/Thumb1855.png
#   inflating: pictures/ThumbDown/Thumb864.png
#   inflating: pictures/ThumbDown/Thumb870.png
#   inflating: pictures/ThumbDown/Thumb1699.png
#   inflating: pictures/ThumbDown/Thumb1841.png
#   inflating: pictures/ThumbDown/Thumb125.png
#   inflating: pictures/ThumbDown/Thumb1114.png
#   inflating: pictures/ThumbDown/Thumb1672.png
#   inflating: pictures/ThumbDown/Thumb643.png
#   inflating: pictures/ThumbDown/Thumb657.png
#   inflating: pictures/ThumbDown/Thumb1666.png
#   inflating: pictures/ThumbDown/Thumb1100.png
#   inflating: pictures/ThumbDown/Thumb131.png
#   inflating: pictures/ThumbDown/Thumb1128.png
#   inflating: pictures/ThumbDown/Thumb119.png
#   inflating: pictures/ThumbDown/Thumb1896.png
#   inflating: pictures/ThumbDown/Thumb1882.png
#   inflating: pictures/ThumbDown/Thumb1909.png
#   inflating: pictures/ThumbDown/Thumb938.png
#   inflating: pictures/ThumbDown/Thumb1921.png
#   inflating: pictures/ThumbDown/Thumb910.png
#   inflating: pictures/ThumbDown/Thumb904.png
#   inflating: pictures/ThumbDown/Thumb1935.png
#   inflating: pictures/ThumbDown/Thumb1060.png
#   inflating: pictures/ThumbDown/Thumb1706.png
#   inflating: pictures/ThumbDown/Thumb737.png
#   inflating: pictures/ThumbDown/Thumb723.png
#   inflating: pictures/ThumbDown/Thumb1712.png
#   inflating: pictures/ThumbDown/Thumb1074.png
#   inflating: pictures/ThumbDown/Thumb1048.png
#   inflating: pictures/ThumbDown/Thumb290.png
#   inflating: pictures/ThumbDown/Thumb284.png
#   inflating: pictures/ThumbDown/Thumb1289.png
#   inflating: pictures/ThumbDown/Thumb535.png
#   inflating: pictures/ThumbDown/Thumb1504.png
#   inflating: pictures/ThumbDown/Thumb1262.png
#   inflating: pictures/ThumbDown/Thumb253.png
#   inflating: pictures/ThumbDown/Thumb247.png
#   inflating: pictures/ThumbDown/Thumb1276.png
#   inflating: pictures/ThumbDown/Thumb1510.png
#   inflating: pictures/ThumbDown/Thumb521.png
#   inflating: pictures/ThumbDown/Thumb32.png
#   inflating: pictures/ThumbDown/Thumb1538.png
#   inflating: pictures/ThumbDown/Thumb509.png
#   inflating: pictures/ThumbDown/Thumb26.png
#   inflating: pictures/ThumbDown/Thumb525.png
#   inflating: pictures/ThumbDown/Thumb1514.png
#   inflating: pictures/ThumbDown/Thumb1272.png
#   inflating: pictures/ThumbDown/Thumb243.png
#   inflating: pictures/ThumbDown/Thumb257.png
#   inflating: pictures/ThumbDown/Thumb1266.png
#   inflating: pictures/ThumbDown/Thumb1500.png
#   inflating: pictures/ThumbDown/Thumb531.png
#   inflating: pictures/ThumbDown/Thumb1528.png
#   inflating: pictures/ThumbDown/Thumb22.png
#   inflating: pictures/ThumbDown/Thumb519.png
#   inflating: pictures/ThumbDown/Thumb36.png
#   inflating: pictures/ThumbDown/Thumb280.png
#   inflating: pictures/ThumbDown/Thumb294.png
#   inflating: pictures/ThumbDown/Thumb1299.png
#   inflating: pictures/ThumbDown/Thumb1070.png
#   inflating: pictures/ThumbDown/Thumb1716.png
#   inflating: pictures/ThumbDown/Thumb727.png
#   inflating: pictures/ThumbDown/Thumb733.png
#   inflating: pictures/ThumbDown/Thumb1702.png
#   inflating: pictures/ThumbDown/Thumb1064.png
#   inflating: pictures/ThumbDown/Thumb1058.png
#   inflating: pictures/ThumbDown/Thumb1919.png
#   inflating: pictures/ThumbDown/Thumb928.png
#   inflating: pictures/ThumbDown/Thumb1931.png
#   inflating: pictures/ThumbDown/Thumb900.png
#   inflating: pictures/ThumbDown/Thumb914.png
#   inflating: pictures/ThumbDown/Thumb1925.png
#   inflating: pictures/ThumbDown/Thumb135.png
#   inflating: pictures/ThumbDown/Thumb1104.png
#   inflating: pictures/ThumbDown/Thumb1662.png
#   inflating: pictures/ThumbDown/Thumb653.png
#   inflating: pictures/ThumbDown/Thumb647.png
#   inflating: pictures/ThumbDown/Thumb1676.png
#   inflating: pictures/ThumbDown/Thumb1110.png
#   inflating: pictures/ThumbDown/Thumb121.png
#   inflating: pictures/ThumbDown/Thumb1138.png
#   inflating: pictures/ThumbDown/Thumb109.png
#   inflating: pictures/ThumbDown/Thumb1886.png
#   inflating: pictures/ThumbDown/Thumb1892.png
#   inflating: pictures/ThumbDown/Thumb690.png
#   inflating: pictures/ThumbDown/Thumb848.png
#   inflating: pictures/ThumbDown/Thumb1879.png
#   inflating: pictures/ThumbDown/Thumb684.png
#   inflating: pictures/ThumbDown/Thumb1845.png
#   inflating: pictures/ThumbDown/Thumb874.png
#   inflating: pictures/ThumbDown/Thumb860.png
#   inflating: pictures/ThumbDown/Thumb1851.png
#   inflating: pictures/ThumbDown/Thumb1689.png
#   inflating: pictures/ThumbDown/Thumb451.png
#   inflating: pictures/ThumbDown/Thumb1460.png
#   inflating: pictures/ThumbDown/Thumb1306.png
#   inflating: pictures/ThumbDown/Thumb337.png
#   inflating: pictures/ThumbDown/Thumb323.png
#   inflating: pictures/ThumbDown/Thumb1312.png
#   inflating: pictures/ThumbDown/Thumb1474.png
#   inflating: pictures/ThumbDown/Thumb445.png
#   inflating: pictures/ThumbDown/Thumb479.png
#   inflating: pictures/ThumbDown/Thumb1448.png
#   inflating: pictures/ThumbDown/Thumb492.png
#   inflating: pictures/ThumbDown/Thumb486.png
#   inflating: pictures/ThumbDown/Thumb487.png
#   inflating: pictures/ThumbDown/Thumb493.png
#   inflating: pictures/ThumbDown/Thumb1449.png
#   inflating: pictures/ThumbDown/Thumb478.png
#   inflating: pictures/ThumbDown/Thumb1313.png
#   inflating: pictures/ThumbDown/Thumb322.png
#   inflating: pictures/ThumbDown/Thumb444.png
#   inflating: pictures/ThumbDown/Thumb1475.png
#   inflating: pictures/ThumbDown/Thumb1461.png
#   inflating: pictures/ThumbDown/Thumb450.png
#   inflating: pictures/ThumbDown/Thumb336.png
#   inflating: pictures/ThumbDown/Thumb1307.png
#   inflating: pictures/ThumbDown/Thumb1688.png
#   inflating: pictures/ThumbDown/Thumb1850.png
#   inflating: pictures/ThumbDown/Thumb861.png
#   inflating: pictures/ThumbDown/Thumb875.png
#   inflating: pictures/ThumbDown/Thumb1844.png
#   inflating: pictures/ThumbDown/Thumb685.png
#   inflating: pictures/ThumbDown/Thumb1878.png
#   inflating: pictures/ThumbDown/Thumb849.png
#   inflating: pictures/ThumbDown/Thumb691.png
#   inflating: pictures/ThumbDown/Thumb1893.png
#   inflating: pictures/ThumbDown/Thumb108.png
#   inflating: pictures/ThumbDown/Thumb1139.png
#   inflating: pictures/ThumbDown/Thumb1887.png
#   inflating: pictures/ThumbDown/Thumb1677.png
#   inflating: pictures/ThumbDown/Thumb646.png
#   inflating: pictures/ThumbDown/Thumb120.png
#   inflating: pictures/ThumbDown/Thumb1111.png
#   inflating: pictures/ThumbDown/Thumb1105.png
#   inflating: pictures/ThumbDown/Thumb134.png
#   inflating: pictures/ThumbDown/Thumb652.png
#   inflating: pictures/ThumbDown/Thumb1663.png
#   inflating: pictures/ThumbDown/Thumb1924.png
#   inflating: pictures/ThumbDown/Thumb915.png
#   inflating: pictures/ThumbDown/Thumb901.png
#   inflating: pictures/ThumbDown/Thumb1930.png
#   inflating: pictures/ThumbDown/Thumb929.png
#   inflating: pictures/ThumbDown/Thumb1918.png
#   inflating: pictures/ThumbDown/Thumb1059.png
#   inflating: pictures/ThumbDown/Thumb1703.png
#   inflating: pictures/ThumbDown/Thumb732.png
#   inflating: pictures/ThumbDown/Thumb1065.png
#   inflating: pictures/ThumbDown/Thumb1071.png
#   inflating: pictures/ThumbDown/Thumb726.png
#   inflating: pictures/ThumbDown/Thumb1717.png
#   inflating: pictures/ThumbDown/Thumb1298.png
#   inflating: pictures/ThumbDown/Thumb295.png
#   inflating: pictures/ThumbDown/Thumb281.png
#   inflating: pictures/ThumbDown/Thumb37.png
#   inflating: pictures/ThumbDown/Thumb518.png
#   inflating: pictures/ThumbDown/Thumb23.png
#   inflating: pictures/ThumbDown/Thumb1529.png
#   inflating: pictures/ThumbDown/Thumb1267.png
#   inflating: pictures/ThumbDown/Thumb256.png
#   inflating: pictures/ThumbDown/Thumb530.png
#   inflating: pictures/ThumbDown/Thumb1501.png
#   inflating: pictures/ThumbDown/Thumb1515.png
#   inflating: pictures/ThumbDown/Thumb524.png
#   inflating: pictures/ThumbDown/Thumb242.png
#   inflating: pictures/ThumbDown/Thumb1273.png
#   inflating: pictures/ThumbDown/Thumb1503.png
#   inflating: pictures/ThumbDown/Thumb532.png
#   inflating: pictures/ThumbDown/Thumb254.png
#   inflating: pictures/ThumbDown/Thumb1265.png
#   inflating: pictures/ThumbDown/Thumb1271.png
#   inflating: pictures/ThumbDown/Thumb240.png
#   inflating: pictures/ThumbDown/Thumb526.png
#   inflating: pictures/ThumbDown/Thumb1517.png
#   inflating: pictures/ThumbDown/Thumb35.png
#   inflating: pictures/ThumbDown/Thumb1259.png
#   inflating: pictures/ThumbDown/Thumb268.png
#   inflating: pictures/ThumbDown/Thumb21.png
#   inflating: pictures/ThumbDown/Thumb297.png
#   inflating: pictures/ThumbDown/Thumb283.png
#   inflating: pictures/ThumbDown/Thumb1067.png
#   inflating: pictures/ThumbDown/Thumb730.png
#   inflating: pictures/ThumbDown/Thumb1701.png
#   inflating: pictures/ThumbDown/Thumb1715.png
#   inflating: pictures/ThumbDown/Thumb724.png
#   inflating: pictures/ThumbDown/Thumb1073.png
#   inflating: pictures/ThumbDown/Thumb718.png
#   inflating: pictures/ThumbDown/Thumb1729.png
#   inflating: pictures/ThumbDown/Thumb1098.png
#   inflating: pictures/ThumbDown/Thumb917.png
#   inflating: pictures/ThumbDown/Thumb1926.png
#   inflating: pictures/ThumbDown/Thumb1932.png
#   inflating: pictures/ThumbDown/Thumb903.png
#   inflating: pictures/ThumbDown/Thumb1113.png
#   inflating: pictures/ThumbDown/Thumb122.png
#   inflating: pictures/ThumbDown/Thumb644.png
#   inflating: pictures/ThumbDown/Thumb1675.png
#   inflating: pictures/ThumbDown/Thumb1661.png
#   inflating: pictures/ThumbDown/Thumb888.png
#   inflating: pictures/ThumbDown/Thumb650.png
#   inflating: pictures/ThumbDown/Thumb136.png
#   inflating: pictures/ThumbDown/Thumb1107.png
#   inflating: pictures/ThumbDown/Thumb1649.png
#   inflating: pictures/ThumbDown/Thumb1891.png
#   inflating: pictures/ThumbDown/Thumb678.png
#   inflating: pictures/ThumbDown/Thumb1885.png
#   inflating: pictures/ThumbDown/Thumb687.png
#   inflating: pictures/ThumbDown/Thumb693.png
#   inflating: pictures/ThumbDown/Thumb863.png
#   inflating: pictures/ThumbDown/Thumb1852.png
#   inflating: pictures/ThumbDown/Thumb1846.png
#   inflating: pictures/ThumbDown/Thumb877.png
#   inflating: pictures/ThumbDown/Thumb1477.png
#   inflating: pictures/ThumbDown/Thumb446.png
#   inflating: pictures/ThumbDown/Thumb320.png
#   inflating: pictures/ThumbDown/Thumb1311.png
#   inflating: pictures/ThumbDown/Thumb1305.png
#   inflating: pictures/ThumbDown/Thumb334.png
#   inflating: pictures/ThumbDown/Thumb452.png
#   inflating: pictures/ThumbDown/Thumb1463.png
#   inflating: pictures/ThumbDown/Thumb308.png
#   inflating: pictures/ThumbDown/Thumb1339.png
#   inflating: pictures/ThumbDown/Thumb485.png
#   inflating: pictures/ThumbDown/Thumb491.png
#   inflating: pictures/ThumbDown/Thumb1488.png
#   inflating: pictures/ThumbDown/Thumb1489.png
#   inflating: pictures/ThumbDown/Thumb490.png
#   inflating: pictures/ThumbDown/Thumb484.png
#   inflating: pictures/ThumbDown/Thumb1338.png
#   inflating: pictures/ThumbDown/Thumb309.png
#   inflating: pictures/ThumbDown/Thumb335.png
#   inflating: pictures/ThumbDown/Thumb1304.png
#   inflating: pictures/ThumbDown/Thumb1462.png
#   inflating: pictures/ThumbDown/Thumb453.png
#   inflating: pictures/ThumbDown/Thumb447.png
#   inflating: pictures/ThumbDown/Thumb1476.png
#   inflating: pictures/ThumbDown/Thumb1310.png
#   inflating: pictures/ThumbDown/Thumb321.png
#   inflating: pictures/ThumbDown/Thumb876.png
#   inflating: pictures/ThumbDown/Thumb1847.png
#   inflating: pictures/ThumbDown/Thumb1853.png
#   inflating: pictures/ThumbDown/Thumb862.png
#   inflating: pictures/ThumbDown/Thumb692.png
#   inflating: pictures/ThumbDown/Thumb686.png
#   inflating: pictures/ThumbDown/Thumb1884.png
#   inflating: pictures/ThumbDown/Thumb679.png
#   inflating: pictures/ThumbDown/Thumb1890.png
#   inflating: pictures/ThumbDown/Thumb1648.png
#   inflating: pictures/ThumbDown/Thumb651.png
#   inflating: pictures/ThumbDown/Thumb889.png
#   inflating: pictures/ThumbDown/Thumb1660.png
#   inflating: pictures/ThumbDown/Thumb1106.png
#   inflating: pictures/ThumbDown/Thumb137.png
#   inflating: pictures/ThumbDown/Thumb123.png
#   inflating: pictures/ThumbDown/Thumb1112.png
#   inflating: pictures/ThumbDown/Thumb1674.png
#   inflating: pictures/ThumbDown/Thumb645.png
#   inflating: pictures/ThumbDown/Thumb902.png
#   inflating: pictures/ThumbDown/Thumb1933.png
#   inflating: pictures/ThumbDown/Thumb1099.png
#   inflating: pictures/ThumbDown/Thumb1927.png
#   inflating: pictures/ThumbDown/Thumb916.png
#   inflating: pictures/ThumbDown/Thumb1728.png
#   inflating: pictures/ThumbDown/Thumb719.png
#   inflating: pictures/ThumbDown/Thumb725.png
#   inflating: pictures/ThumbDown/Thumb1714.png
#   inflating: pictures/ThumbDown/Thumb1072.png
#   inflating: pictures/ThumbDown/Thumb1066.png
#   inflating: pictures/ThumbDown/Thumb1700.png
#   inflating: pictures/ThumbDown/Thumb731.png
#   inflating: pictures/ThumbDown/Thumb282.png
#   inflating: pictures/ThumbDown/Thumb296.png
#   inflating: pictures/ThumbDown/Thumb20.png
#   inflating: pictures/ThumbDown/Thumb34.png
#   inflating: pictures/ThumbDown/Thumb269.png
#   inflating: pictures/ThumbDown/Thumb1258.png
#   inflating: pictures/ThumbDown/Thumb241.png
#   inflating: pictures/ThumbDown/Thumb1270.png
#   inflating: pictures/ThumbDown/Thumb1516.png
#   inflating: pictures/ThumbDown/Thumb527.png
#   inflating: pictures/ThumbDown/Thumb533.png
#   inflating: pictures/ThumbDown/Thumb1502.png
#   inflating: pictures/ThumbDown/Thumb1264.png
#   inflating: pictures/ThumbDown/Thumb255.png
#   inflating: pictures/ThumbDown/Thumb1559.png
#   inflating: pictures/ThumbDown/Thumb53.png
#   inflating: pictures/ThumbDown/Thumb568.png
#   inflating: pictures/ThumbDown/Thumb47.png
#   inflating: pictures/ThumbDown/Thumb554.png
#   inflating: pictures/ThumbDown/Thumb1565.png
#   inflating: pictures/ThumbDown/Thumb1203.png
#   inflating: pictures/ThumbDown/Thumb232.png
#   inflating: pictures/ThumbDown/Thumb226.png
#   inflating: pictures/ThumbDown/Thumb1217.png
#   inflating: pictures/ThumbDown/Thumb1571.png
#   inflating: pictures/ThumbDown/Thumb540.png
#   inflating: pictures/ThumbDown/Thumb90.png
#   inflating: pictures/ThumbDown/Thumb84.png
#   inflating: pictures/ThumbDown/Thumb597.png
#   inflating: pictures/ThumbDown/Thumb583.png
#   inflating: pictures/ThumbDown/Thumb1983.png
#   inflating: pictures/ThumbDown/Thumb1997.png
#   inflating: pictures/ThumbDown/Thumb1029.png
#   inflating: pictures/ThumbDown/Thumb1001.png
#   inflating: pictures/ThumbDown/Thumb1767.png
#   inflating: pictures/ThumbDown/Thumb756.png
#   inflating: pictures/ThumbDown/Thumb742.png
#   inflating: pictures/ThumbDown/Thumb1773.png
#   inflating: pictures/ThumbDown/Thumb1015.png
#   inflating: pictures/ThumbDown/Thumb1798.png
#   inflating: pictures/ThumbDown/Thumb1940.png
#   inflating: pictures/ThumbDown/Thumb971.png
#   inflating: pictures/ThumbDown/Thumb965.png
#   inflating: pictures/ThumbDown/Thumb1954.png
#   inflating: pictures/ThumbDown/Thumb795.png
#   inflating: pictures/ThumbDown/Thumb1968.png
#   inflating: pictures/ThumbDown/Thumb959.png
#   inflating: pictures/ThumbDown/Thumb781.png
#   inflating: pictures/ThumbDown/Thumb1149.png
#   inflating: pictures/ThumbDown/Thumb178.png
#   inflating: pictures/ThumbDown/Thumb144.png
#   inflating: pictures/ThumbDown/Thumb1175.png
#   inflating: pictures/ThumbDown/Thumb1613.png
#   inflating: pictures/ThumbDown/Thumb622.png
#   inflating: pictures/ThumbDown/Thumb636.png
#   inflating: pictures/ThumbDown/Thumb1607.png
#   inflating: pictures/ThumbDown/Thumb1161.png
#   inflating: pictures/ThumbDown/Thumb150.png
#   inflating: pictures/ThumbDown/Thumb1834.png
#   inflating: pictures/ThumbDown/Thumb805.png
#   inflating: pictures/ThumbDown/Thumb811.png
#   inflating: pictures/ThumbDown/Thumb1820.png
#   inflating: pictures/ThumbDown/Thumb187.png
#   inflating: pictures/ThumbDown/Thumb839.png
#   inflating: pictures/ThumbDown/Thumb1808.png
#   inflating: pictures/ThumbDown/Thumb193.png
#   inflating: pictures/ThumbDown/Thumb408.png
#   inflating: pictures/ThumbDown/Thumb1439.png
#   inflating: pictures/ThumbDown/Thumb420.png
#   inflating: pictures/ThumbDown/Thumb1411.png
#   inflating: pictures/ThumbDown/Thumb1377.png
#   inflating: pictures/ThumbDown/Thumb346.png
#   inflating: pictures/ThumbDown/Thumb352.png
#   inflating: pictures/ThumbDown/Thumb1363.png
#   inflating: pictures/ThumbDown/Thumb1405.png
#   inflating: pictures/ThumbDown/Thumb434.png
#   inflating: pictures/ThumbDown/Thumb1388.png
#   inflating: pictures/ThumbDown/Thumb385.png
#   inflating: pictures/ThumbDown/Thumb391.png
#   inflating: pictures/ThumbDown/Thumb390.png
#   inflating: pictures/ThumbDown/Thumb384.png
#   inflating: pictures/ThumbDown/Thumb1389.png
#   inflating: pictures/ThumbDown/Thumb1362.png
#   inflating: pictures/ThumbDown/Thumb353.png
#   inflating: pictures/ThumbDown/Thumb435.png
#   inflating: pictures/ThumbDown/Thumb1404.png
#   inflating: pictures/ThumbDown/Thumb1410.png
#   inflating: pictures/ThumbDown/Thumb421.png
#   inflating: pictures/ThumbDown/Thumb347.png
#   inflating: pictures/ThumbDown/Thumb1376.png
#   inflating: pictures/ThumbDown/Thumb1438.png
#   inflating: pictures/ThumbDown/Thumb409.png
#   inflating: pictures/ThumbDown/Thumb192.png
#   inflating: pictures/ThumbDown/Thumb186.png
#   inflating: pictures/ThumbDown/Thumb1809.png
#   inflating: pictures/ThumbDown/Thumb838.png
#   inflating: pictures/ThumbDown/Thumb1821.png
#   inflating: pictures/ThumbDown/Thumb810.png
#   inflating: pictures/ThumbDown/Thumb804.png
#   inflating: pictures/ThumbDown/Thumb1835.png
#   inflating: pictures/ThumbDown/Thumb1606.png
#   inflating: pictures/ThumbDown/Thumb637.png
#   inflating: pictures/ThumbDown/Thumb151.png
#   inflating: pictures/ThumbDown/Thumb1160.png
#   inflating: pictures/ThumbDown/Thumb1174.png
#   inflating: pictures/ThumbDown/Thumb145.png
#   inflating: pictures/ThumbDown/Thumb623.png
#   inflating: pictures/ThumbDown/Thumb1612.png
#   inflating: pictures/ThumbDown/Thumb179.png
#   inflating: pictures/ThumbDown/Thumb1148.png
#   inflating: pictures/ThumbDown/Thumb780.png
#   inflating: pictures/ThumbDown/Thumb958.png
#   inflating: pictures/ThumbDown/Thumb1969.png
#   inflating: pictures/ThumbDown/Thumb794.png
#   inflating: pictures/ThumbDown/Thumb1955.png
#   inflating: pictures/ThumbDown/Thumb964.png
#   inflating: pictures/ThumbDown/Thumb970.png
#   inflating: pictures/ThumbDown/Thumb1941.png
#   inflating: pictures/ThumbDown/Thumb1799.png
#   inflating: pictures/ThumbDown/Thumb1772.png
#   inflating: pictures/ThumbDown/Thumb743.png
#   inflating: pictures/ThumbDown/Thumb1014.png
#   inflating: pictures/ThumbDown/Thumb1000.png
#   inflating: pictures/ThumbDown/Thumb757.png
#   inflating: pictures/ThumbDown/Thumb1766.png
#   inflating: pictures/ThumbDown/Thumb1996.png
#   inflating: pictures/ThumbDown/Thumb1028.png
#   inflating: pictures/ThumbDown/Thumb1982.png
#   inflating: pictures/ThumbDown/Thumb582.png
#   inflating: pictures/ThumbDown/Thumb596.png
#   inflating: pictures/ThumbDown/Thumb85.png
#   inflating: pictures/ThumbDown/Thumb91.png
#   inflating: pictures/ThumbDown/Thumb1216.png
#   inflating: pictures/ThumbDown/Thumb227.png
#   inflating: pictures/ThumbDown/Thumb541.png
#   inflating: pictures/ThumbDown/Thumb1570.png
#   inflating: pictures/ThumbDown/Thumb1564.png
#   inflating: pictures/ThumbDown/Thumb555.png
#   inflating: pictures/ThumbDown/Thumb233.png
#   inflating: pictures/ThumbDown/Thumb1202.png
#   inflating: pictures/ThumbDown/Thumb46.png
#   inflating: pictures/ThumbDown/Thumb569.png
#   inflating: pictures/ThumbDown/Thumb52.png
#   inflating: pictures/ThumbDown/Thumb1558.png
#   inflating: pictures/ThumbDown/Thumb44.png
#   inflating: pictures/ThumbDown/Thumb1228.png
#   inflating: pictures/ThumbDown/Thumb219.png
#   inflating: pictures/ThumbDown/Thumb50.png
#   inflating: pictures/ThumbDown/Thumb1572.png
#   inflating: pictures/ThumbDown/Thumb78.png
#   inflating: pictures/ThumbDown/Thumb543.png
#   inflating: pictures/ThumbDown/Thumb225.png
#   inflating: pictures/ThumbDown/Thumb1214.png
#   inflating: pictures/ThumbDown/Thumb1200.png
#   inflating: pictures/ThumbDown/Thumb231.png
#   inflating: pictures/ThumbDown/Thumb557.png
#   inflating: pictures/ThumbDown/Thumb1566.png
#   inflating: pictures/ThumbDown/Thumb87.png
#   inflating: pictures/ThumbDown/Thumb93.png
#   inflating: pictures/ThumbDown/Thumb1599.png
#   inflating: pictures/ThumbDown/Thumb580.png
#   inflating: pictures/ThumbDown/Thumb594.png
#   inflating: pictures/ThumbDown/Thumb1994.png
#   inflating: pictures/ThumbDown/Thumb769.png
#   inflating: pictures/ThumbDown/Thumb1980.png
#   inflating: pictures/ThumbDown/Thumb1758.png
#   inflating: pictures/ThumbDown/Thumb1016.png
#   inflating: pictures/ThumbDown/Thumb741.png
#   inflating: pictures/ThumbDown/Thumb999.png
#   inflating: pictures/ThumbDown/Thumb1770.png
#   inflating: pictures/ThumbDown/Thumb1764.png
#   inflating: pictures/ThumbDown/Thumb755.png
#   inflating: pictures/ThumbDown/Thumb1002.png
#   inflating: pictures/ThumbDown/Thumb966.png
#   inflating: pictures/ThumbDown/Thumb1957.png
#   inflating: pictures/ThumbDown/Thumb1943.png
#   inflating: pictures/ThumbDown/Thumb972.png
#   inflating: pictures/ThumbDown/Thumb782.png
#   inflating: pictures/ThumbDown/Thumb796.png
#   inflating: pictures/ThumbDown/Thumb1638.png
#   inflating: pictures/ThumbDown/Thumb609.png
#   inflating: pictures/ThumbDown/Thumb1162.png
#   inflating: pictures/ThumbDown/Thumb153.png
#   inflating: pictures/ThumbDown/Thumb635.png
#   inflating: pictures/ThumbDown/Thumb1604.png
#   inflating: pictures/ThumbDown/Thumb1610.png
#   inflating: pictures/ThumbDown/Thumb621.png
#   inflating: pictures/ThumbDown/Thumb147.png
#   inflating: pictures/ThumbDown/Thumb1176.png
#   inflating: pictures/ThumbDown/Thumb812.png
#   inflating: pictures/ThumbDown/Thumb1823.png
#   inflating: pictures/ThumbDown/Thumb1837.png
#   inflating: pictures/ThumbDown/Thumb806.png
#   inflating: pictures/ThumbDown/Thumb1189.png
#   inflating: pictures/ThumbDown/Thumb190.png
#   inflating: pictures/ThumbDown/Thumb184.png
#   inflating: pictures/ThumbDown/Thumb379.png
#   inflating: pictures/ThumbDown/Thumb1348.png
#   inflating: pictures/ThumbDown/Thumb1406.png
#   inflating: pictures/ThumbDown/Thumb437.png
#   inflating: pictures/ThumbDown/Thumb351.png
#   inflating: pictures/ThumbDown/Thumb1360.png
#   inflating: pictures/ThumbDown/Thumb1374.png
#   inflating: pictures/ThumbDown/Thumb345.png
#   inflating: pictures/ThumbDown/Thumb423.png
#   inflating: pictures/ThumbDown/Thumb1412.png
#   inflating: pictures/ThumbDown/Thumb392.png
#   inflating: pictures/ThumbDown/Thumb386.png
#   inflating: pictures/ThumbDown/Thumb387.png
#   inflating: pictures/ThumbDown/Thumb393.png
#   inflating: pictures/ThumbDown/Thumb344.png
#   inflating: pictures/ThumbDown/Thumb1375.png
#   inflating: pictures/ThumbDown/Thumb1413.png
#   inflating: pictures/ThumbDown/Thumb422.png
#   inflating: pictures/ThumbDown/Thumb436.png
#   inflating: pictures/ThumbDown/Thumb1407.png
#   inflating: pictures/ThumbDown/Thumb1361.png
#   inflating: pictures/ThumbDown/Thumb350.png
#   inflating: pictures/ThumbDown/Thumb1349.png
#   inflating: pictures/ThumbDown/Thumb378.png
#   inflating: pictures/ThumbDown/Thumb185.png
#   inflating: pictures/ThumbDown/Thumb191.png
#   inflating: pictures/ThumbDown/Thumb807.png
#   inflating: pictures/ThumbDown/Thumb1836.png
#   inflating: pictures/ThumbDown/Thumb1188.png
#   inflating: pictures/ThumbDown/Thumb1822.png
#   inflating: pictures/ThumbDown/Thumb813.png
#   inflating: pictures/ThumbDown/Thumb620.png
#   inflating: pictures/ThumbDown/Thumb1611.png
#   inflating: pictures/ThumbDown/Thumb1177.png
#   inflating: pictures/ThumbDown/Thumb146.png
#   inflating: pictures/ThumbDown/Thumb152.png
#   inflating: pictures/ThumbDown/Thumb1163.png
#   inflating: pictures/ThumbDown/Thumb1605.png
#   inflating: pictures/ThumbDown/Thumb634.png
#   inflating: pictures/ThumbDown/Thumb608.png
#   inflating: pictures/ThumbDown/Thumb1639.png
#   inflating: pictures/ThumbDown/Thumb797.png
#   inflating: pictures/ThumbDown/Thumb783.png
#   inflating: pictures/ThumbDown/Thumb973.png
#   inflating: pictures/ThumbDown/Thumb1942.png
#   inflating: pictures/ThumbDown/Thumb1956.png
#   inflating: pictures/ThumbDown/Thumb967.png
#   inflating: pictures/ThumbDown/Thumb754.png
#   inflating: pictures/ThumbDown/Thumb1765.png
#   inflating: pictures/ThumbDown/Thumb1003.png
#   inflating: pictures/ThumbDown/Thumb1017.png
#   inflating: pictures/ThumbDown/Thumb1771.png
#   inflating: pictures/ThumbDown/Thumb998.png
#   inflating: pictures/ThumbDown/Thumb740.png
#   inflating: pictures/ThumbDown/Thumb1759.png
#   inflating: pictures/ThumbDown/Thumb1981.png
#   inflating: pictures/ThumbDown/Thumb768.png
#   inflating: pictures/ThumbDown/Thumb1995.png
#   inflating: pictures/ThumbDown/Thumb595.png
#   inflating: pictures/ThumbDown/Thumb581.png
#   inflating: pictures/ThumbDown/Thumb1598.png
#   inflating: pictures/ThumbDown/Thumb92.png
#   inflating: pictures/ThumbDown/Thumb86.png
#   inflating: pictures/ThumbDown/Thumb230.png
#   inflating: pictures/ThumbDown/Thumb1201.png
#   inflating: pictures/ThumbDown/Thumb1567.png
#   inflating: pictures/ThumbDown/Thumb556.png
#   inflating: pictures/ThumbDown/Thumb542.png
#   inflating: pictures/ThumbDown/Thumb79.png
#   inflating: pictures/ThumbDown/Thumb1573.png
#   inflating: pictures/ThumbDown/Thumb1215.png
#   inflating: pictures/ThumbDown/Thumb224.png
#   inflating: pictures/ThumbDown/Thumb51.png
#   inflating: pictures/ThumbDown/Thumb45.png
#   inflating: pictures/ThumbDown/Thumb218.png
#   inflating: pictures/ThumbDown/Thumb1229.png
#   inflating: pictures/ThumbDown/Thumb220.png
#   inflating: pictures/ThumbDown/Thumb1211.png
#   inflating: pictures/ThumbDown/Thumb1577.png
#   inflating: pictures/ThumbDown/Thumb546.png
#   inflating: pictures/ThumbDown/Thumb552.png
#   inflating: pictures/ThumbDown/Thumb1563.png
#   inflating: pictures/ThumbDown/Thumb69.png
#   inflating: pictures/ThumbDown/Thumb1205.png
#   inflating: pictures/ThumbDown/Thumb234.png
#   inflating: pictures/ThumbDown/Thumb41.png
#   inflating: pictures/ThumbDown/Thumb55.png
#   inflating: pictures/ThumbDown/Thumb208.png
#   inflating: pictures/ThumbDown/Thumb1239.png
#   inflating: pictures/ThumbDown/Thumb585.png
#   inflating: pictures/ThumbDown/Thumb9.png
#   inflating: pictures/ThumbDown/Thumb591.png
#   inflating: pictures/ThumbDown/Thumb82.png
#   inflating: pictures/ThumbDown/Thumb1588.png
#   inflating: pictures/ThumbDown/Thumb96.png
#   inflating: pictures/ThumbDown/Thumb744.png
#   inflating: pictures/ThumbDown/Thumb1775.png
#   inflating: pictures/ThumbDown/Thumb1013.png
#   inflating: pictures/ThumbDown/Thumb1007.png
#   inflating: pictures/ThumbDown/Thumb1761.png
#   inflating: pictures/ThumbDown/Thumb750.png
#   inflating: pictures/ThumbDown/Thumb988.png
#   inflating: pictures/ThumbDown/Thumb1991.png
#   inflating: pictures/ThumbDown/Thumb1749.png
#   inflating: pictures/ThumbDown/Thumb778.png
#   inflating: pictures/ThumbDown/Thumb1985.png
#   inflating: pictures/ThumbDown/Thumb787.png
#   inflating: pictures/ThumbDown/Thumb793.png
#   inflating: pictures/ThumbDown/Thumb963.png
#   inflating: pictures/ThumbDown/Thumb1952.png
#   inflating: pictures/ThumbDown/Thumb1946.png
#   inflating: pictures/ThumbDown/Thumb977.png
#   inflating: pictures/ThumbDown/Thumb630.png
#   inflating: pictures/ThumbDown/Thumb1601.png
#   inflating: pictures/ThumbDown/Thumb1167.png
#   inflating: pictures/ThumbDown/Thumb156.png
#   inflating: pictures/ThumbDown/Thumb142.png
#   inflating: pictures/ThumbDown/Thumb1173.png
#   inflating: pictures/ThumbDown/Thumb1615.png
#   inflating: pictures/ThumbDown/Thumb624.png
#   inflating: pictures/ThumbDown/Thumb618.png
#   inflating: pictures/ThumbDown/Thumb1629.png
#   inflating: pictures/ThumbDown/Thumb195.png
#   inflating: pictures/ThumbDown/Thumb181.png
#   inflating: pictures/ThumbDown/Thumb817.png
#   inflating: pictures/ThumbDown/Thumb1826.png
#   inflating: pictures/ThumbDown/Thumb1198.png
#   inflating: pictures/ThumbDown/Thumb1832.png
#   inflating: pictures/ThumbDown/Thumb803.png
#   inflating: pictures/ThumbDown/Thumb354.png
#   inflating: pictures/ThumbDown/Thumb1365.png
#   inflating: pictures/ThumbDown/Thumb1403.png
#   inflating: pictures/ThumbDown/Thumb432.png
#   inflating: pictures/ThumbDown/Thumb426.png
#   inflating: pictures/ThumbDown/Thumb1417.png
#   inflating: pictures/ThumbDown/Thumb1371.png
#   inflating: pictures/ThumbDown/Thumb340.png
#   inflating: pictures/ThumbDown/Thumb1359.png
#   inflating: pictures/ThumbDown/Thumb368.png
#   inflating: pictures/ThumbDown/Thumb397.png
#   inflating: pictures/ThumbDown/Thumb383.png
#   inflating: pictures/ThumbDown/Thumb382.png
#   inflating: pictures/ThumbDown/Thumb396.png
#   inflating: pictures/ThumbDown/Thumb369.png
#   inflating: pictures/ThumbDown/Thumb1358.png
#   inflating: pictures/ThumbDown/Thumb1416.png
#   inflating: pictures/ThumbDown/Thumb427.png
#   inflating: pictures/ThumbDown/Thumb341.png
#   inflating: pictures/ThumbDown/Thumb1370.png
#   inflating: pictures/ThumbDown/Thumb1364.png
#   inflating: pictures/ThumbDown/Thumb355.png
#   inflating: pictures/ThumbDown/Thumb433.png
#   inflating: pictures/ThumbDown/Thumb1402.png
#   inflating: pictures/ThumbDown/Thumb802.png
#   inflating: pictures/ThumbDown/Thumb1833.png
#   inflating: pictures/ThumbDown/Thumb1827.png
#   inflating: pictures/ThumbDown/Thumb816.png
#   inflating: pictures/ThumbDown/Thumb1199.png
#   inflating: pictures/ThumbDown/Thumb180.png
#   inflating: pictures/ThumbDown/Thumb194.png
#   inflating: pictures/ThumbDown/Thumb1628.png
#   inflating: pictures/ThumbDown/Thumb619.png
#   inflating: pictures/ThumbDown/Thumb1172.png
#   inflating: pictures/ThumbDown/Thumb143.png
#   inflating: pictures/ThumbDown/Thumb625.png
#   inflating: pictures/ThumbDown/Thumb1614.png
#   inflating: pictures/ThumbDown/Thumb1600.png
#   inflating: pictures/ThumbDown/Thumb631.png
#   inflating: pictures/ThumbDown/Thumb157.png
#   inflating: pictures/ThumbDown/Thumb1166.png
#   inflating: pictures/ThumbDown/Thumb976.png
#   inflating: pictures/ThumbDown/Thumb1947.png
#   inflating: pictures/ThumbDown/Thumb1953.png
#   inflating: pictures/ThumbDown/Thumb962.png
#   inflating: pictures/ThumbDown/Thumb792.png
#   inflating: pictures/ThumbDown/Thumb786.png
#   inflating: pictures/ThumbDown/Thumb1984.png
#   inflating: pictures/ThumbDown/Thumb779.png
#   inflating: pictures/ThumbDown/Thumb1748.png
#   inflating: pictures/ThumbDown/Thumb1990.png
#   inflating: pictures/ThumbDown/Thumb1006.png
#   inflating: pictures/ThumbDown/Thumb989.png
#   inflating: pictures/ThumbDown/Thumb751.png
#   inflating: pictures/ThumbDown/Thumb1760.png
#   inflating: pictures/ThumbDown/Thumb1774.png
#   inflating: pictures/ThumbDown/Thumb745.png
#   inflating: pictures/ThumbDown/Thumb1012.png
#   inflating: pictures/ThumbDown/Thumb97.png
#   inflating: pictures/ThumbDown/Thumb1589.png
#   inflating: pictures/ThumbDown/Thumb83.png
#   inflating: pictures/ThumbDown/Thumb590.png
#   inflating: pictures/ThumbDown/Thumb8.png
#   inflating: pictures/ThumbDown/Thumb584.png
#   inflating: pictures/ThumbDown/Thumb54.png
#   inflating: pictures/ThumbDown/Thumb1238.png
#   inflating: pictures/ThumbDown/Thumb209.png
#   inflating: pictures/ThumbDown/Thumb40.png
#   inflating: pictures/ThumbDown/Thumb68.png
#   inflating: pictures/ThumbDown/Thumb1562.png
#   inflating: pictures/ThumbDown/Thumb553.png
#   inflating: pictures/ThumbDown/Thumb235.png
#   inflating: pictures/ThumbDown/Thumb1204.png
#   inflating: pictures/ThumbDown/Thumb1210.png
#   inflating: pictures/ThumbDown/Thumb221.png
#   inflating: pictures/ThumbDown/Thumb547.png
#   inflating: pictures/ThumbDown/Thumb1576.png
#   inflating: pictures/ThumbDown/Thumb1206.png
#   inflating: pictures/ThumbDown/Thumb237.png
#   inflating: pictures/ThumbDown/Thumb551.png
#   inflating: pictures/ThumbDown/Thumb1560.png
#   inflating: pictures/ThumbDown/Thumb1574.png
#   inflating: pictures/ThumbDown/Thumb545.png
#   inflating: pictures/ThumbDown/Thumb223.png
#   inflating: pictures/ThumbDown/Thumb1212.png
#   inflating: pictures/ThumbDown/Thumb56.png
#   inflating: pictures/ThumbDown/Thumb579.png
#   inflating: pictures/ThumbDown/Thumb1548.png
#   inflating: pictures/ThumbDown/Thumb42.png
#   inflating: pictures/ThumbDown/Thumb592.png
#   inflating: pictures/ThumbDown/Thumb586.png
#   inflating: pictures/ThumbDown/Thumb95.png
#   inflating: pictures/ThumbDown/Thumb81.png
#   inflating: pictures/ThumbDown/Thumb1762.png
#   inflating: pictures/ThumbDown/Thumb753.png
#   inflating: pictures/ThumbDown/Thumb1004.png
#   inflating: pictures/ThumbDown/Thumb1010.png
#   inflating: pictures/ThumbDown/Thumb747.png
#   inflating: pictures/ThumbDown/Thumb1776.png
#   inflating: pictures/ThumbDown/Thumb1986.png
#   inflating: pictures/ThumbDown/Thumb1038.png
#   inflating: pictures/ThumbDown/Thumb1992.png
#   inflating: pictures/ThumbDown/Thumb948.png
#   inflating: pictures/ThumbDown/Thumb790.png
#   inflating: pictures/ThumbDown/Thumb1979.png
#   inflating: pictures/ThumbDown/Thumb784.png
#   inflating: pictures/ThumbDown/Thumb1945.png
#   inflating: pictures/ThumbDown/Thumb974.png
#   inflating: pictures/ThumbDown/Thumb960.png
#   inflating: pictures/ThumbDown/Thumb1789.png
#   inflating: pictures/ThumbDown/Thumb1951.png
#   inflating: pictures/ThumbDown/Thumb1616.png
#   inflating: pictures/ThumbDown/Thumb627.png
#   inflating: pictures/ThumbDown/Thumb141.png
#   inflating: pictures/ThumbDown/Thumb1170.png
#   inflating: pictures/ThumbDown/Thumb1164.png
#   inflating: pictures/ThumbDown/Thumb155.png
#   inflating: pictures/ThumbDown/Thumb633.png
#   inflating: pictures/ThumbDown/Thumb1602.png
#   inflating: pictures/ThumbDown/Thumb169.png
#   inflating: pictures/ThumbDown/Thumb1158.png
#   inflating: pictures/ThumbDown/Thumb182.png
#   inflating: pictures/ThumbDown/Thumb196.png
#   inflating: pictures/ThumbDown/Thumb1819.png
#   inflating: pictures/ThumbDown/Thumb828.png
#   inflating: pictures/ThumbDown/Thumb1831.png
#   inflating: pictures/ThumbDown/Thumb800.png
#   inflating: pictures/ThumbDown/Thumb814.png
#   inflating: pictures/ThumbDown/Thumb1825.png
#   inflating: pictures/ThumbDown/Thumb1372.png
#   inflating: pictures/ThumbDown/Thumb343.png
#   inflating: pictures/ThumbDown/Thumb425.png
#   inflating: pictures/ThumbDown/Thumb1414.png
#   inflating: pictures/ThumbDown/Thumb1400.png
#   inflating: pictures/ThumbDown/Thumb431.png
#   inflating: pictures/ThumbDown/Thumb357.png
#   inflating: pictures/ThumbDown/Thumb1366.png
#   inflating: pictures/ThumbDown/Thumb1428.png
#   inflating: pictures/ThumbDown/Thumb419.png
#   inflating: pictures/ThumbDown/Thumb380.png
#   inflating: pictures/ThumbDown/Thumb394.png
#   inflating: pictures/ThumbDown/Thumb1399.png
#   inflating: pictures/ThumbDown/Thumb1398.png
#   inflating: pictures/ThumbDown/Thumb395.png
#   inflating: pictures/ThumbDown/Thumb381.png
#   inflating: pictures/ThumbDown/Thumb418.png
#   inflating: pictures/ThumbDown/Thumb1429.png
#   inflating: pictures/ThumbDown/Thumb430.png
#   inflating: pictures/ThumbDown/Thumb1401.png
#   inflating: pictures/ThumbDown/Thumb1367.png
#   inflating: pictures/ThumbDown/Thumb356.png
#   inflating: pictures/ThumbDown/Thumb342.png
#   inflating: pictures/ThumbDown/Thumb1373.png
#   inflating: pictures/ThumbDown/Thumb1415.png
#   inflating: pictures/ThumbDown/Thumb424.png
#   inflating: pictures/ThumbDown/Thumb1824.png
#   inflating: pictures/ThumbDown/Thumb815.png
#   inflating: pictures/ThumbDown/Thumb801.png
#   inflating: pictures/ThumbDown/Thumb1830.png
#   inflating: pictures/ThumbDown/Thumb197.png
#   inflating: pictures/ThumbDown/Thumb829.png
#   inflating: pictures/ThumbDown/Thumb1818.png
#   inflating: pictures/ThumbDown/Thumb183.png
#   inflating: pictures/ThumbDown/Thumb1159.png
#   inflating: pictures/ThumbDown/Thumb168.png
#   inflating: pictures/ThumbDown/Thumb154.png
#   inflating: pictures/ThumbDown/Thumb1165.png
#   inflating: pictures/ThumbDown/Thumb1603.png
#   inflating: pictures/ThumbDown/Thumb632.png
#   inflating: pictures/ThumbDown/Thumb626.png
#   inflating: pictures/ThumbDown/Thumb1617.png
#   inflating: pictures/ThumbDown/Thumb1171.png
#   inflating: pictures/ThumbDown/Thumb140.png
#   inflating: pictures/ThumbDown/Thumb1950.png
#   inflating: pictures/ThumbDown/Thumb1788.png
#   inflating: pictures/ThumbDown/Thumb961.png
#   inflating: pictures/ThumbDown/Thumb975.png
#   inflating: pictures/ThumbDown/Thumb1944.png
#   inflating: pictures/ThumbDown/Thumb785.png
#   inflating: pictures/ThumbDown/Thumb1978.png
#   inflating: pictures/ThumbDown/Thumb791.png
#   inflating: pictures/ThumbDown/Thumb949.png
#   inflating: pictures/ThumbDown/Thumb1993.png
#   inflating: pictures/ThumbDown/Thumb1987.png
#   inflating: pictures/ThumbDown/Thumb1039.png
#   inflating: pictures/ThumbDown/Thumb1011.png
#   inflating: pictures/ThumbDown/Thumb1777.png
#   inflating: pictures/ThumbDown/Thumb746.png
#   inflating: pictures/ThumbDown/Thumb752.png
#   inflating: pictures/ThumbDown/Thumb1763.png
#   inflating: pictures/ThumbDown/Thumb1005.png
#   inflating: pictures/ThumbDown/Thumb80.png
#   inflating: pictures/ThumbDown/Thumb94.png
#   inflating: pictures/ThumbDown/Thumb587.png
#   inflating: pictures/ThumbDown/Thumb593.png
#   inflating: pictures/ThumbDown/Thumb43.png
#   inflating: pictures/ThumbDown/Thumb1549.png
#   inflating: pictures/ThumbDown/Thumb578.png
#   inflating: pictures/ThumbDown/Thumb57.png
#   inflating: pictures/ThumbDown/Thumb544.png
#   inflating: pictures/ThumbDown/Thumb1575.png
#   inflating: pictures/ThumbDown/Thumb1213.png
#   inflating: pictures/ThumbDown/Thumb222.png
#   inflating: pictures/ThumbDown/Thumb236.png
#   inflating: pictures/ThumbDown/Thumb1207.png
#   inflating: pictures/ThumbDown/Thumb1561.png
#   inflating: pictures/ThumbDown/Thumb550.png
#   inflating: pictures/ThumbUp/Thumb549.png
#   inflating: pictures/ThumbUp/Thumb1578.png
#   inflating: pictures/ThumbUp/Thumb72.png
#   inflating: pictures/ThumbUp/Thumb66.png
#   inflating: pictures/ThumbUp/Thumb1544.png
#   inflating: pictures/ThumbUp/Thumb575.png
#   inflating: pictures/ThumbUp/Thumb213.png
#   inflating: pictures/ThumbUp/Thumb1222.png
#   inflating: pictures/ThumbUp/Thumb1236.png
#   inflating: pictures/ThumbUp/Thumb207.png
#   inflating: pictures/ThumbUp/Thumb561.png
#   inflating: pictures/ThumbUp/Thumb1550.png
# ...
#   inflating: pictures/Palm/frame_07_01_0091.png
#   inflating: pictures/Palm/frame_07_01_0085.png
#   inflating: pictures/Palm/frame_02_01_0123.png
#   inflating: pictures/Palm/frame_00_01_0062.png
#   inflating: pictures/Palm/frame_08_01_0190.png
#   inflating: pictures/Palm/frame_00_01_0076.png
#   inflating: pictures/Palm/frame_08_01_0184.png
#   inflating: pictures/Palm/frame_02_01_0137.png
#   inflating: pictures/Palm/frame_02_01_0136.png
#   inflating: pictures/Palm/frame_08_01_0185.png
#   inflating: pictures/Palm/frame_00_01_0077.png
#   inflating: pictures/Palm/frame_08_01_0191.png
#   inflating: pictures/Palm/frame_00_01_0063.png
#   inflating: pictures/Palm/frame_02_01_0122.png
#   inflating: pictures/Palm/frame_07_01_0084.png
#   inflating: pictures/Palm/frame_07_01_0090.png
#   inflating: pictures/Palm/frame_08_01_0146.png
#   inflating: pictures/Palm/frame_08_01_0152.png
#   inflating: pictures/Palm/frame_07_01_0047.png
#   inflating: pictures/Palm/frame_00_01_0088.png
#   inflating: pictures/Palm/frame_05_01_0106.png
#   inflating: pictures/Palm/frame_05_01_0112.png
#   inflating: pictures/Palm/frame_07_01_0053.png
#   inflating: pictures/Palm/frame_01_01_0179.png
#   inflating: pictures/Palm/frame_03_01_0038.png
#   inflating: pictures/Palm/frame_03_01_0004.png
#   inflating: pictures/Palm/frame_01_01_0145.png
#   inflating: pictures/Palm/frame_01_01_0151.png
#   inflating: pictures/Palm/frame_03_01_0010.png
#   inflating: pictures/Palm/frame_06_01_0175.png
#   inflating: pictures/Palm/frame_09_01_0048.png
#   inflating: pictures/Palm/frame_04_01_0034.png
#   inflating: pictures/Palm/frame_04_01_0020.png
#   inflating: pictures/Palm/frame_06_01_0161.png
#   inflating: pictures/Palm/frame_01_01_0186.png
#   inflating: pictures/Palm/frame_04_01_0008.png
#   inflating: pictures/Palm/frame_09_01_0074.png
#   inflating: pictures/Palm/frame_06_01_0149.png
#   inflating: pictures/Palm/frame_01_01_0192.png
#   inflating: pictures/Palm/frame_09_01_0060.png
#   inflating: pictures/Palm/frame_04_01_0183.png
#   inflating: pictures/Palm/frame_03_01_0158.png
#   inflating: pictures/Palm/frame_01_01_0019.png
#   inflating: pictures/Palm/frame_04_01_0197.png
#   inflating: pictures/Palm/frame_03_01_0170.png
#   inflating: pictures/Palm/frame_01_01_0031.png
#   inflating: pictures/Palm/frame_01_01_0025.png
#   inflating: pictures/Palm/frame_03_01_0164.png
#   inflating: pictures/Palm/frame_06_01_0001.png
#   inflating: pictures/Palm/frame_04_01_0140.png
#   inflating: pictures/Palm/frame_09_01_0128.png
#   inflating: pictures/Palm/frame_04_01_0154.png
#   inflating: pictures/Palm/frame_06_01_0015.png
#   inflating: pictures/Palm/frame_09_01_0100.png
#   inflating: pictures/Palm/frame_06_01_0029.png
#   inflating: pictures/Palm/frame_04_01_0168.png
#   inflating: pictures/Palm/frame_09_01_0114.png
#   inflating: pictures/Palm/frame_02_01_0042.png
#   inflating: pictures/Palm/frame_00_01_0103.png
#   inflating: pictures/Palm/frame_00_01_0117.png
#   inflating: pictures/Palm/frame_05_01_0099.png
#   inflating: pictures/Palm/frame_02_01_0056.png
#   inflating: pictures/Palm/frame_08_01_0032.png
#   inflating: pictures/Palm/frame_02_01_0081.png
#   inflating: pictures/Palm/frame_02_01_0095.png
#   inflating: pictures/Palm/frame_08_01_0026.png
#   inflating: pictures/Palm/frame_07_01_0133.png
#   inflating: pictures/Palm/frame_05_01_0072.png
#   inflating: pictures/Palm/frame_05_01_0066.png
#   inflating: pictures/Palm/frame_07_01_0127.png
#   inflating: pictures/Palm/frame_08_01_0022.png
#   inflating: pictures/Palm/frame_02_01_0091.png
#   inflating: pictures/Palm/frame_02_01_0085.png
#   inflating: pictures/Palm/frame_08_01_0036.png
#   inflating: pictures/Palm/frame_07_01_0123.png
#   inflating: pictures/Palm/frame_05_01_0062.png
#   inflating: pictures/Palm/frame_05_01_0076.png
#   inflating: pictures/Palm/frame_07_01_0137.png
#   inflating: pictures/Palm/frame_02_01_0052.png
#   inflating: pictures/Palm/frame_00_01_0113.png
#   inflating: pictures/Palm/frame_05_01_0089.png
#   inflating: pictures/Palm/frame_00_01_0107.png
#   inflating: pictures/Palm/frame_02_01_0046.png
#   inflating: pictures/Palm/frame_06_01_0011.png
#   inflating: pictures/Palm/frame_04_01_0150.png
#   inflating: pictures/Palm/frame_04_01_0144.png
#   inflating: pictures/Palm/frame_09_01_0138.png
#   inflating: pictures/Palm/frame_06_01_0005.png
#   inflating: pictures/Palm/frame_09_01_0110.png
#   inflating: pictures/Palm/frame_06_01_0039.png
#   inflating: pictures/Palm/frame_09_01_0104.png
#   inflating: pictures/Palm/frame_04_01_0178.png
#   inflating: pictures/Palm/frame_04_01_0193.png
#   inflating: pictures/Palm/frame_03_01_0148.png
#   inflating: pictures/Palm/frame_04_01_0187.png
#   inflating: pictures/Palm/frame_01_01_0009.png
#   inflating: pictures/Palm/frame_03_01_0160.png
#   inflating: pictures/Palm/frame_01_01_0021.png
#   inflating: pictures/Palm/frame_01_01_0035.png
#   inflating: pictures/Palm/frame_03_01_0174.png
#   inflating: pictures/Palm/frame_06_01_0165.png
#   inflating: pictures/Palm/frame_04_01_0024.png
#   inflating: pictures/Palm/frame_09_01_0058.png
#   inflating: pictures/Palm/frame_04_01_0030.png
#   inflating: pictures/Palm/frame_06_01_0171.png
#   inflating: pictures/Palm/frame_09_01_0064.png
#   inflating: pictures/Palm/frame_04_01_0018.png
#   inflating: pictures/Palm/frame_01_01_0196.png
#   inflating: pictures/Palm/frame_06_01_0159.png
#   inflating: pictures/Palm/frame_09_01_0070.png
#   inflating: pictures/Palm/frame_01_01_0182.png
#   inflating: pictures/Palm/frame_01_01_0169.png
#   inflating: pictures/Palm/frame_03_01_0028.png
#   inflating: pictures/Palm/frame_03_01_0014.png
#   inflating: pictures/Palm/frame_01_01_0155.png
#   inflating: pictures/Palm/frame_01_01_0141.png
#   inflating: pictures/Palm/frame_08_01_0156.png
#   inflating: pictures/Palm/frame_08_01_0142.png
#   inflating: pictures/Palm/frame_07_01_0057.png
#   inflating: pictures/Palm/frame_05_01_0116.png
#   inflating: pictures/Palm/frame_00_01_0098.png
#   inflating: pictures/Palm/frame_05_01_0102.png
#   inflating: pictures/Palm/frame_07_01_0043.png
#   inflating: pictures/Palm/frame_02_01_0126.png
#   inflating: pictures/Palm/frame_00_01_0067.png
#   inflating: pictures/Palm/frame_08_01_0195.png
#   inflating: pictures/Palm/frame_00_01_0073.png
#   inflating: pictures/Palm/frame_08_01_0181.png
#   inflating: pictures/Palm/frame_02_01_0132.png
#   inflating: pictures/Palm/frame_07_01_0094.png
#   inflating: pictures/Palm/frame_07_01_0080.png
#   inflating: pictures/Palm/frame_07_01_0081.png
#   inflating: pictures/Palm/frame_07_01_0095.png
#   inflating: pictures/Palm/frame_02_01_0133.png
#   inflating: pictures/Palm/frame_08_01_0180.png
#   inflating: pictures/Palm/frame_00_01_0072.png
#   inflating: pictures/Palm/frame_08_01_0194.png
#   inflating: pictures/Palm/frame_00_01_0066.png
#   inflating: pictures/Palm/frame_02_01_0127.png
#   inflating: pictures/Palm/frame_07_01_0042.png
#   inflating: pictures/Palm/frame_05_01_0103.png
#   inflating: pictures/Palm/frame_00_01_0099.png
#   inflating: pictures/Palm/frame_05_01_0117.png
#   inflating: pictures/Palm/frame_07_01_0056.png
#   inflating: pictures/Palm/frame_08_01_0143.png
#   inflating: pictures/Palm/frame_08_01_0157.png
#   inflating: pictures/Palm/frame_03_01_0001.png
#   inflating: pictures/Palm/frame_01_01_0140.png
#   inflating: pictures/Palm/frame_01_01_0154.png
#   inflating: pictures/Palm/frame_03_01_0015.png
#   inflating: pictures/Palm/frame_03_01_0029.png
#   inflating: pictures/Palm/frame_01_01_0168.png
#   inflating: pictures/Palm/frame_01_01_0183.png
#   inflating: pictures/Palm/frame_09_01_0071.png
#   inflating: pictures/Palm/frame_06_01_0158.png
#   inflating: pictures/Palm/frame_01_01_0197.png
#   inflating: pictures/Palm/frame_04_01_0019.png
#   inflating: pictures/Palm/frame_09_01_0065.png
#   inflating: pictures/Palm/frame_06_01_0170.png
#   inflating: pictures/Palm/frame_04_01_0031.png
#   inflating: pictures/Palm/frame_09_01_0059.png
#   inflating: pictures/Palm/frame_04_01_0025.png
#   inflating: pictures/Palm/frame_06_01_0164.png
#   inflating: pictures/Palm/frame_03_01_0175.png
#   inflating: pictures/Palm/frame_01_01_0034.png
#   inflating: pictures/Palm/frame_01_01_0020.png
#   inflating: pictures/Palm/frame_03_01_0161.png
#   inflating: pictures/Palm/frame_01_01_0008.png
#   inflating: pictures/Palm/frame_04_01_0186.png
#   inflating: pictures/Palm/frame_03_01_0149.png
#   inflating: pictures/Palm/frame_04_01_0192.png
#   inflating: pictures/Palm/frame_04_01_0179.png
#   inflating: pictures/Palm/frame_09_01_0105.png
#   inflating: pictures/Palm/frame_06_01_0038.png
#   inflating: pictures/Palm/frame_09_01_0111.png
#   inflating: pictures/Palm/frame_06_01_0004.png
#   inflating: pictures/Palm/frame_09_01_0139.png
#   inflating: pictures/Palm/frame_04_01_0145.png
#   inflating: pictures/Palm/frame_04_01_0151.png
#   inflating: pictures/Palm/frame_06_01_0010.png
#   inflating: pictures/Palm/frame_02_01_0047.png
#   inflating: pictures/Palm/frame_00_01_0106.png
#   inflating: pictures/Palm/frame_05_01_0088.png
#   inflating: pictures/Palm/frame_00_01_0112.png
#   inflating: pictures/Palm/frame_02_01_0053.png
#   inflating: pictures/Palm/frame_07_01_0136.png
#   inflating: pictures/Palm/frame_05_01_0077.png
#   inflating: pictures/Palm/frame_05_01_0063.png
#   inflating: pictures/Palm/frame_07_01_0122.png
#   inflating: pictures/Palm/frame_08_01_0037.png
#   inflating: pictures/Palm/frame_02_01_0084.png
#   inflating: pictures/Palm/frame_02_01_0090.png
#   inflating: pictures/Palm/frame_08_01_0023.png
#   inflating: pictures/Palm/frame_02_01_0086.png
#   inflating: pictures/Palm/frame_07_01_0108.png
#   inflating: pictures/Palm/frame_08_01_0035.png
#   inflating: pictures/Palm/frame_05_01_0049.png
#   inflating: pictures/Palm/frame_08_01_0021.png
#   inflating: pictures/Palm/frame_02_01_0092.png
#   inflating: pictures/Palm/frame_05_01_0075.png
#   inflating: pictures/Palm/frame_08_01_0009.png
#   inflating: pictures/Palm/frame_07_01_0134.png
#   inflating: pictures/Palm/frame_07_01_0120.png
#   inflating: pictures/Palm/frame_05_01_0061.png
#   inflating: pictures/Palm/frame_00_01_0104.png
#   inflating: pictures/Palm/frame_02_01_0045.png
#   inflating: pictures/Palm/frame_02_01_0051.png
#   inflating: pictures/Palm/frame_00_01_0110.png
#   inflating: pictures/Palm/frame_02_01_0079.png
#   inflating: pictures/Palm/frame_00_01_0138.png
#   inflating: pictures/Palm/frame_04_01_0147.png
#   inflating: pictures/Palm/frame_03_01_0188.png
#   inflating: pictures/Palm/frame_06_01_0006.png
#   inflating: pictures/Palm/frame_06_01_0012.png
#   inflating: pictures/Palm/frame_04_01_0153.png
#   inflating: pictures/Palm/frame_09_01_0107.png
#   inflating: pictures/Palm/frame_09_01_0113.png
#   inflating: pictures/Palm/frame_04_01_0184.png
#   inflating: pictures/Palm/frame_04_01_0190.png
#   inflating: pictures/Palm/frame_01_01_0036.png
#   inflating: pictures/Palm/frame_03_01_0177.png
#   inflating: pictures/Palm/frame_03_01_0163.png
#   inflating: pictures/Palm/frame_01_01_0022.png
#   inflating: pictures/Palm/frame_04_01_0033.png
#   inflating: pictures/Palm/frame_06_01_0172.png
#   inflating: pictures/Palm/frame_06_01_0166.png
#   inflating: pictures/Palm/frame_04_01_0027.png
#   inflating: pictures/Palm/frame_09_01_0073.png
#   inflating: pictures/Palm/frame_01_01_0181.png
#   inflating: pictures/Palm/frame_09_01_0067.png
#   inflating: pictures/Palm/frame_01_01_0195.png
#   inflating: pictures/Palm/frame_09_01_0098.png
#   inflating: pictures/Palm/frame_01_01_0142.png
#   inflating: pictures/Palm/frame_03_01_0003.png
#   inflating: pictures/Palm/frame_03_01_0017.png
#   inflating: pictures/Palm/frame_06_01_0199.png
#   inflating: pictures/Palm/frame_01_01_0156.png
#   inflating: pictures/Palm/frame_08_01_0141.png
#   inflating: pictures/Palm/frame_08_01_0155.png
#   inflating: pictures/Palm/frame_05_01_0129.png
#   inflating: pictures/Palm/frame_07_01_0068.png
#   inflating: pictures/Palm/frame_05_01_0101.png
#   inflating: pictures/Palm/frame_07_01_0040.png
#   inflating: pictures/Palm/frame_07_01_0054.png
#   inflating: pictures/Palm/frame_05_01_0115.png
#   inflating: pictures/Palm/frame_08_01_0169.png
#   inflating: pictures/Palm/frame_00_01_0070.png
#   inflating: pictures/Palm/frame_08_01_0182.png
#   inflating: pictures/Palm/frame_02_01_0131.png
#   inflating: pictures/Palm/frame_02_01_0125.png
#   inflating: pictures/Palm/frame_00_01_0064.png
#   inflating: pictures/Palm/frame_08_01_0196.png
#   inflating: pictures/Palm/frame_07_01_0083.png
#   inflating: pictures/Palm/frame_00_01_0058.png
#   inflating: pictures/Palm/frame_02_01_0119.png
#   inflating: pictures/Palm/frame_07_01_0097.png
#   inflating: pictures/Palm/frame_07_01_0096.png
#   inflating: pictures/Palm/frame_02_01_0118.png
#   inflating: pictures/Palm/frame_00_01_0059.png
#   inflating: pictures/Palm/frame_07_01_0082.png
#   inflating: pictures/Palm/frame_03_01_0200.png
#   inflating: pictures/Palm/frame_08_01_0197.png
#   inflating: pictures/Palm/frame_00_01_0065.png
#   inflating: pictures/Palm/frame_02_01_0124.png
#   inflating: pictures/Palm/frame_02_01_0130.png
#   inflating: pictures/Palm/frame_08_01_0183.png
#   inflating: pictures/Palm/frame_00_01_0071.png
#   inflating: pictures/Palm/frame_08_01_0168.png
#   inflating: pictures/Palm/frame_05_01_0114.png
#   inflating: pictures/Palm/frame_07_01_0055.png
#   inflating: pictures/Palm/frame_07_01_0041.png
#   inflating: pictures/Palm/frame_05_01_0100.png
#   inflating: pictures/Palm/frame_07_01_0069.png
#   inflating: pictures/Palm/frame_05_01_0128.png
#   inflating: pictures/Palm/frame_08_01_0154.png
#   inflating: pictures/Palm/frame_08_01_0140.png
#   inflating: pictures/Palm/frame_01_01_0157.png
#   inflating: pictures/Palm/frame_06_01_0198.png
#   inflating: pictures/Palm/frame_03_01_0016.png
#   inflating: pictures/Palm/frame_03_01_0002.png
#   inflating: pictures/Palm/frame_01_01_0143.png
#   inflating: pictures/Palm/frame_09_01_0099.png
#   inflating: pictures/Palm/frame_01_01_0194.png
#   inflating: pictures/Palm/frame_09_01_0066.png
#   inflating: pictures/Palm/frame_01_01_0180.png
#   inflating: pictures/Palm/frame_09_01_0072.png
#   inflating: pictures/Palm/frame_04_01_0026.png
#   inflating: pictures/Palm/frame_06_01_0167.png
#   inflating: pictures/Palm/frame_06_01_0173.png
#   inflating: pictures/Palm/frame_04_01_0032.png
#   inflating: pictures/Palm/frame_01_01_0023.png
#   inflating: pictures/Palm/frame_03_01_0162.png
#   inflating: pictures/Palm/frame_03_01_0176.png
#   inflating: pictures/Palm/frame_01_01_0037.png
#   inflating: pictures/Palm/frame_04_01_0191.png
#   inflating: pictures/Palm/frame_04_01_0185.png
#   inflating: pictures/Palm/frame_09_01_0112.png
#   inflating: pictures/Palm/frame_09_01_0106.png
#   inflating: pictures/Palm/frame_04_01_0152.png
#   inflating: pictures/Palm/frame_06_01_0013.png
#   inflating: pictures/Palm/frame_06_01_0007.png
#   inflating: pictures/Palm/frame_03_01_0189.png
#   inflating: pictures/Palm/frame_04_01_0146.png
#   inflating: pictures/Palm/frame_00_01_0139.png
#   inflating: pictures/Palm/frame_02_01_0078.png
#   inflating: pictures/Palm/frame_00_01_0111.png
#   inflating: pictures/Palm/frame_02_01_0050.png
#   inflating: pictures/Palm/frame_02_01_0044.png
#   inflating: pictures/Palm/frame_00_01_0105.png
#   inflating: pictures/Palm/frame_05_01_0060.png
#   inflating: pictures/Palm/frame_07_01_0121.png
#   inflating: pictures/Palm/frame_07_01_0135.png
#   inflating: pictures/Palm/frame_08_01_0008.png
#   inflating: pictures/Palm/frame_05_01_0074.png
#   inflating: pictures/Palm/frame_02_01_0093.png
#   inflating: pictures/Palm/frame_08_01_0020.png
#   inflating: pictures/Palm/frame_05_01_0048.png
#   inflating: pictures/Palm/frame_08_01_0034.png
#   inflating: pictures/Palm/frame_07_01_0109.png
#   inflating: pictures/Palm/frame_02_01_0087.png

# %%
import cv2
import numpy as np
import pandas as pd

import torch 
import torch.nn as nn
import torch.optim
from torchvision import datasets, transforms

# %%
# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

device = 'cpu'
if not train_on_gpu:
    print('CUDA is not available.  Training on CPU ...')
else:
    device = 'cuda'
    print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %%
torch.__version__
# Out:
# '1.8.1+cu101'

# %%
labels = {
    "ThumbUp": 0,
    "ThumbDown": 1,
    "Ok": 2,
    "Palm": 3
}

class LeapMotionDataset(torch.utils.data.Dataset):
  # Dataset for Leap Motion data
  def __init__(self, csv_file, file_col, lbl_col, text2lbl, transforms=None):
    """
    Initialize Dataset

    params:
      - csv_file: Path to CSV
      - file_col: Column corresponding to file name
      - lbl_col: Column corresponding to label column
      - text2lbl: Numerical representation of labels
      - transforms: Transforms to apply to imgs
    """

    self.csv = pd.read_csv(csv_file)
    self.file_col = file_col
    self.lbl_col = lbl_col
    self.labels = text2lbl
    self.transforms = transforms

  def __len__(self):
    """
    Returns the length of dataset
    """

    return len(self.csv)

  def __getitem__(self, idx):
    """
    Get item from dataset

    params:
      - idx: Index of data record to get.
    """

    img = cv2.imread(self.csv.loc[idx][self.file_col])

    # Thumb image have different channel orgainization that we need to account for
    # We also need to rearrange channels. PyTorch expect C x H x W
    if "Thumb" not in self.csv.loc[idx][self.lbl_col ]:
      img = img.astype(np.float).transpose(2, 0, 1)
    else:
      img = img.astype(np.float).transpose(2, 1, 0)
    label = self.csv.loc[idx][self.lbl_col]

    # Convert to tensor and apply transforms
    img = torch.from_numpy(img)
    if self.transforms:
      img = self.transforms(img)

    sample = {"img": img, "label": self.labels[label]}

    return sample

class TinyHGRDataset(torch.utils.data.Dataset):
  # Dataset for TinyHGR data
  def __init__(self, csv_file, file_col, lbl_col, text2lbl, transforms=None):
    """
    Initialize Dataset

    params:
      - csv_file: Path to CSV
      - file_col: Column corresponding to file name
      - lbl_col: Column corresponding to label column
      - text2lbl: Numerical representation of labels
      - transforms: Transforms to apply to imgs
    """
    self.csv = pd.read_csv(csv_file)
    self.file_col = file_col
    self.lbl_col = lbl_col
    self.labels = text2lbl
    self.transforms = transforms

  def __len__(self):
    """
    Returns the length of dataset
    """

    return len(self.csv)

  def __getitem__(self, idx):
    """
    Get item from dataset

    params:
      - idx: Index of data record to get.
    """
    img = cv2.imread(self.csv.loc[idx][self.file_col])
    if img.shape[0] != 480 and img.shape[1] != 640:
      img = cv2.resize(img, (640, 480))

    # Rearrange channels. PyTorch expect C x H x W
    img = img.astype(np.float).transpose(2, 0, 1)
    
    label = self.csv.loc[idx][self.lbl_col]

    # Convert to tensor and apply transforms
    img = torch.from_numpy(img)
    if self.transforms:
      img = self.transforms(img)

    sample = {"img": img, "label": self.labels[label]}

    return sample

# %%
def set_parameter_requires_grad(model, extract_features):
  """
  Extract features from a pretrained model

  params:
  model -- pretrained model
  extract_features -- True or False, indicating whether or not to extract features from model
  """
  if extract_features:
    for param in model.parameters():
      param.requires_grad = False

# %%
from torchvision.models import resnet18, resnet50, inception_v3

def load_and_initalize(model_name, num_classes, extract_features=True):
  """
  Load and initialize a pretrained model. Classification layer of models are set to be trained,
  while the rest of the model remains frozen. 

  params:
    - model_name: Pretrained model name to load
    - num_classes: Number of classes for the model
    - extract_features: Whether or not to extract features from the model
  """
  input_size = 0
  model = None

  if model_name == "resnet18":
    model = resnet18(pretrained=True)

    # Extract model features
    set_parameter_requires_grad(model, extract_features)

    # Set classification layers to fit number of classes for model
    num_ftrs = model.fc.in_features
    model.fc = nn.Linear(num_ftrs, num_classes)
    input_size = 224
  elif model_name == "resnet50":
    model = resnet50(pretrained=True)

    # Extract model features
    set_parameter_requires_grad(model, extract_features)

    # Set classification layers to fit number of classes for model
    num_ftrs = model.fc.in_features
    model.fc = nn.Linear(num_ftrs, num_classes)
    input_size = 224
  elif model_name == "inception_v3":
    model = inception_v3(pretrained=True)
    # Extract model features
    set_parameter_requires_grad(model, extract_features)
    
    # Handle the auxilary net
    num_ftrs = model.AuxLogits.fc.in_features
    model.AuxLogits.fc = nn.Linear(num_ftrs, num_classes)

    # Handle primary net
    num_ftrs = model.fc.in_features
    model.fc = nn.Linear(num_ftrs, num_classes)
    input_size = 299

  return model, input_size

# %%
def train_model(model, train_dl, optimizer, loss_fn, is_inception=False, valid_dl = None, epochs=10):
  """
  Train a model

  params:
    - model: Model to use for training
    - train_dl: DataLoader for training data
    - optimizer: Optimizer to use for training
    - loss_fn: Loss function for training
    - is_inception: Indicator for whether or not we are training an inception network.
    - valid_dl: Validation DataLoader (optional)
    - epochs: Number of epochs for training

  returns:
    - train_loss: List of training losses
    - val_loss: list of validation losses
  """
  model.to(device)

  for ep in range(1, epochs + 1):
    train_loss, val_loss = [], []
    print("---" * 3, "Epoch", ep, "---" * 3)
    model.train()
    for batch in train_dl:
      optimizer.zero_grad()
      img = batch["img"].float().to(device)
      labels = batch["label"].to(device)
      if is_inception:
        out, aux = model(img)
        loss_out = loss_fn(out, labels)
        loss_aux = loss_fn(aux, labels)
        loss = loss_out + 0.4*loss_aux
      else:
        out = model(img)
        loss = loss_fn(out, batch["label"].to(device))
      train_loss.append(loss.item())
      loss.backward()
      optimizer.step()
    print("Training Loss: ", np.mean(train_loss))
    
    if valid_dl is not None:
      model = model.eval()
      for batch in valid_dl:
        img = batch["img"].float().to(device)
        labels = batch["label"].to(device)
        out = model(img)
        loss = loss_fn(out, batch["label"].to(device))
        val_loss.append(loss.item())
      print("Validation Loss: ", np.mean(val_loss))

  return train_loss, val_loss

# %%
def test_model(model, testloader):
  """
  Test a model

  params:
    - model: Model to test
    - testloader: DataLoader for test set

  returns: 
    - y_true: true labels
    - y_pred: final predictions
  """
  model.eval()
  y_true, y_pred = [], []
  for batch in testloader:
    img = batch["img"].float().to(device)
    out = model(img)
    y_true.extend(batch["label"])
    probabilities = torch.softmax(model(img), dim=1)
    predicted_class = torch.argmax(probabilities, dim=1)
    y_pred.extend(predicted_class.cpu())
  return y_true, y_pred

# %%
# Modified: https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Greens):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred, labels=classes)

    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

# %%
model, img_size = load_and_initalize("inception_v3", 4)
print(model)
# Out:
# Inception3(
#   (Conv2d_1a_3x3): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2a_3x3): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2b_3x3): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Conv2d_3b_1x1): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_4a_3x3): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Mixed_5b): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5c): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5d): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6a): InceptionB(
#     (branch3x3): BasicConv2d(
#       (conv): Conv2d(288, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6b): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6c): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6d): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6e): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (AuxLogits): InceptionAux(
#     (conv0): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): BasicConv2d(
#       (conv): Conv2d(128, 768, kernel_size=(5, 5), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (fc): Linear(in_features=768, out_features=4, bias=True)
#   )
#   (Mixed_7a): InceptionD(
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2): BasicConv2d(
#       (conv): Conv2d(192, 320, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7b): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(1280, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(1280, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(1280, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7c): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(2048, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(2048, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(2048, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(2048, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=2048, out_features=4, bias=True)
# )

# %%
transforms_list = transforms.Compose([transforms.Resize(img_size), 
                                 transforms.RandomCrop(img_size),
                                 transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

# %%
# Build Datasets
train_ds = LeapMotionDataset("/content/drive/MyDrive/HandGestures/data/LeapMotion/train_split.csv",
                            "file", "label", labels, transforms=transforms_list)
valid_ds = LeapMotionDataset("/content/drive/MyDrive/HandGestures/data/LeapMotion/valid_split.csv",
                            "file", "label", labels, transforms=transforms.Compose([transforms.Resize(img_size),
                                 transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])]))
test_ds = LeapMotionDataset("/content/drive/MyDrive/HandGestures/data/LeapMotion/test_split.csv",
                            "file", "label", labels, transforms=transforms.Compose([transforms.Resize(img_size),
                                 transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])]))

# %%
# Build DataLoaders
trainloader = torch.utils.data.DataLoader(train_ds, batch_size=16, shuffle=True)
validloader = torch.utils.data.DataLoader(valid_ds, batch_size=16, shuffle=True)
testloader = torch.utils.data.DataLoader(test_ds, batch_size=16, shuffle=True)

# %%
optimizer = torch.optim.SGD(model.parameters(), 0.001)
loss_fn = torch.nn.CrossEntropyLoss()

train_loss, valid_loss = train_model(model, trainloader, optimizer, loss_fn, valid_dl=validloader, is_inception=True, epochs=10)
# Out:
# --------- Epoch 1 ---------
# Training Loss:  1.650763956705729
# Validation Loss:  1.2784043830118061
# --------- Epoch 2 ---------
# Training Loss:  1.422851122053046
# Validation Loss:  1.2188192966543598
# --------- Epoch 3 ---------
# Training Loss:  1.2599166970503957
# Validation Loss:  1.1710512130348771
# --------- Epoch 4 ---------
# Training Loss:  1.1608891386734812
# Validation Loss:  1.1256936001188962
# --------- Epoch 5 ---------
# Training Loss:  1.0871741520731073
# Validation Loss:  1.0749533411897259
# --------- Epoch 6 ---------
# Training Loss:  1.0199171800362437
# Validation Loss:  1.0524026957558996
# --------- Epoch 7 ---------
# Training Loss:  0.9631064329230995
# Validation Loss:  1.0232714690543987
# --------- Epoch 8 ---------
# Training Loss:  0.9128382101393583
# Validation Loss:  0.997348916751367
# --------- Epoch 9 ---------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-013c4af11d31> in <module>()
#       2 loss_fn = torch.nn.CrossEntropyLoss()
#       3
# ----> 4 train_loss, valid_loss = train_model(model, trainloader, optimizer, loss_fn, valid_dl=validloader, is_inception=True, epochs=10)
#
# <ipython-input-24-2a1a8e69f0f0> in train_model(model, train_dl, optimizer, loss_fn, is_inception, valid_dl, epochs)
#      22     print("---" * 3, "Epoch", ep, "---" * 3)
#      23     model.train()
# ---> 24     for batch in train_dl:
#      25       optimizer.zero_grad()
#      26       img = batch["img"].float().to(device)
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     515             if self._sampler_iter is None:
#     516                 self._reset()
# --> 517             data = self._next_data()
#     518             self._num_yielded += 1
#     519             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     555     def _next_data(self):
#     556         index = self._next_index()  # may raise StopIteration
# --> 557         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     558         if self._pin_memory:
#     559             data = _utils.pin_memory.pin_memory(data)
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# <ipython-input-21-820ffe0c228c> in __getitem__(self, idx)
#      54     img = torch.from_numpy(img)
#      55     if self.transforms:
# ---> 56       img = self.transforms(img)
#      57
#      58     sample = {"img": img, "label": self.labels[label]}
#
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      58     def __call__(self, img):
#      59         for t in self.transforms:
# ---> 60             img = t(img)
#      61         return img
#      62
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py in forward(self, img)
#     271             PIL Image or Tensor: Rescaled image.
#     272         """
# --> 273         return F.resize(img, self.size, self.interpolation)
#     274
#     275     def __repr__(self):
#
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/functional.py in resize(img, size, interpolation)
#     375         return F_pil.resize(img, size=size, interpolation=pil_interpolation)
#     376
# --> 377     return F_t.resize(img, size=size, interpolation=interpolation.value)
#     378
#     379
#
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/functional_tensor.py in resize(img, size, interpolation)
#     513     align_corners = False if interpolation in ["bilinear", "bicubic"] else None
#     514
# --> 515     img = interpolate(img, size=[size_h, size_w], mode=interpolation, align_corners=align_corners)
#     516
#     517     if interpolation == "bicubic" and out_dtype == torch.uint8:
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py in interpolate(input, size, scale_factor, mode, align_corners, recompute_scale_factor)
#    3552     if input.dim() == 4 and mode == "bilinear":
#    3553         assert align_corners is not None
# -> 3554         return torch._C._nn.upsample_bilinear2d(input, output_size, align_corners, scale_factors)
#    3555     if input.dim() == 5 and mode == "trilinear":
#    3556         assert align_corners is not None
#
# KeyboardInterrupt:

# %% [markdown]
# ### Stopped training the network because the model started overfitting. It would be best to implement an early stopping mechanism

# %%
y_true, y_pred = test_model(model, testloader)
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      1.000     0.496     0.663       117
#            1      0.990     0.912     0.949       113
#            2      0.925     0.741     0.823       116
#            3      0.547     1.000     0.707       110
#
#     accuracy                          0.783       456
#    macro avg      0.866     0.787     0.786       456
# weighted avg      0.869     0.783     0.785       456

# %%
torch.save(model.state_dict(), "/content/drive/MyDrive//HandGestures/models/inception-v3_leapmotion.pkl")

# %%
class2lbl = {c: lbl for lbl, c in labels.items()}
y_true_lbls = [class2lbl[c.item()] for c in y_true]
y_pred_lbls = [class2lbl[c.item()] for c in y_pred]

plot_confusion_matrix(y_true_lbls, y_pred_lbls, classes=list(labels.keys()), title="Confusion Matrix, InceptionV3")
# Out:
# [[ 58   1   7  51]
#  [  0 103   0  10]
#  [  0   0  86  30]
#  [  0   0   0 110]]
