# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
def subsample_data(data, samp_proportion):
  """
  Create a random subset of the data
  
  params:
    - data: Data to make a subset of
    - samp_proportion: Amount of data to keep

  returns:
    - subset: subset of the data
  """
  size = len(data)
  samp_proportion = 0.7
  indices = np.array(range(0, size))

  rand_sample = np.random.choice(indices, size=int(size*samp_proportion), replace=False)
  subset = data.loc[rand_sample, :]
  return subset

# %%
# Create a subset of the data: This will be used with the TinyHGR data
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/HandGestures/data/LeapMotion/all_data.csv")

# %%
data_subset = subsample_data(data, 0.7)

# %%
data_subset
# Out:
#                                              file      label
# 7508  /content/pictures/Palm/frame_00_01_0063.png       Palm
# 4251      /content/pictures/ThumbUp/Thumb1371.png    ThumbUp
# 5218       /content/pictures/ThumbUp/Thumb762.png    ThumbUp
# 4357      /content/pictures/ThumbUp/Thumb1418.png    ThumbUp
# 1532    /content/pictures/Ok/frame_04_07_0023.png         Ok
# ...                                           ...        ...
# 2901     /content/pictures/ThumbDown/Thumb261.png  ThumbDown
# 6285  /content/pictures/Palm/frame_07_01_0140.png       Palm
# 4070      /content/pictures/ThumbUp/Thumb1451.png    ThumbUp
# 2806    /content/pictures/ThumbDown/Thumb1791.png  ThumbDown
# 4664        /content/pictures/ThumbUp/Thumb58.png    ThumbUp
#
# [5320 rows x 2 columns]

# %%
data_subset.to_csv("/content/drive/MyDrive/HandGestures/data/LeapMotion/data_subset.csv", index=False)
